# %%
from os import path, getcwd
from hundir_la_flota_con_clases import *
import neat
import random
import pickle

# %%
def eval_genomes(genomes, config):
    nets = []
    ge = []
    almirantes = []
    
    for genome_id, genome in genomes:
        genome.fitness = 0
        net = neat.nn.FeedForwardNetwork.create(genome, config)
        nets.append(net)
        almirantes.append(Almirante("IA", True))
        ge.append(genome)
        
    for indice, almirante in enumerate(almirantes):
        # Variable de juego
        posicions_conocidas = [(i, j) for i in range(10) for j in range(10)]
        end = True
        
        while (end):
            # Elegir una coordenada para disparar
            tablero_enemigo_numpy = almirante.tablero_enemigo_para_IA()
            output = nets[almirantes.index(almirante)].activate(tablero_enemigo_numpy)
            fila, columna = almirante.salida_de_red_a_indice(np.argmax(output))

            if (fila, columna) in posicions_conocidas:
                resultado_del_disparo = almirante.recibir_disparo(fila, columna)
                posicions_conocidas.remove((fila, columna))

            else:
                ge[indice].fitness -= 1
                if len(posicions_conocidas) > 0:
                    fila, columna = posicions_conocidas[-1]
                    posicions_conocidas.pop()
                    resultado_del_disparo = almirante.recibir_disparo(fila, columna)
                    
            if resultado_del_disparo == "A":
                ge[indice].fitness -= 1
            elif resultado_del_disparo == "T":
                ge[indice].fitness += 10
            elif resultado_del_disparo == "H":
                ge[indice].fitness += 10

            # Actualizar mapa con (Tocado, Hundido y Agua)
            almirante.actualizar_tras_disparo(resultado_del_disparo, fila, columna)

            if almirante.soy_ganador():
                ge[indice].fitness += 20
                end = False

# %%
def run(config_file):
    """
    Ejecuta el algoritmo NEAT para entrenar una red neuronal para que juegue
    al hundir la flota.
    :param config_file: dirección del archivo de configuración
    """
    config = neat.config.Config(neat.DefaultGenome, neat.DefaultReproduction,
                         neat.DefaultSpeciesSet, neat.DefaultStagnation,
                         config_file)

    # Crear la población de en base a la configutación 
    p = neat.Population(config)

    # Mostrar un resumen al final de cada generación
    p.add_reporter(neat.StdOutReporter(False))
    stats = neat.StatisticsReporter()
    p.add_reporter(stats)
    
    geneaciones = 200
    nombre_del_archivo_entrenado = "red_mamadisima"
    # El iniciar el entrenamiento
    winner = p.run(eval_genomes, geneaciones)
    with open(f"{nombre_del_archivo_entrenado}_generaciones{geneaciones}.pkl", "wb") as f:
        pickle.dump(winner, f)
        
    # Estadisticas finales
    print('\nEl mejor genoma:\n{!s}'.format(winner))

# %%
if __name__ == '__main__':
    # Abrimos el archivo de configuración para el entrenamiento
    config_path = path.join(getcwd(), 'config-feedforward.txt')
    run(config_path)
# Out:
#  ****** Running generation 0 ******
#
# Population's average fitness: 75.40000 stdev: 11.76095
# Best fitness: 113.00000 - size: (104, 800) - species 1 - id 36
# Average adjusted fitness: 0.248
# Mean genetic distance 2.441, standard deviation 0.226
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 4.259 sec
#
#  ****** Running generation 1 ******
#
# Population's average fitness: 76.42000 stdev: 8.24400
# Best fitness: 100.00000 - size: (104, 794) - species 1 - id 83
# Average adjusted fitness: 0.326
# Mean genetic distance 2.111, standard deviation 0.423
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 4.071 sec (4.165 average)
#
#  ****** Running generation 2 ******
#
# Population's average fitness: 76.42000 stdev: 9.25870
# Best fitness: 99.00000 - size: (104, 791) - species 1 - id 139
# Average adjusted fitness: 0.355
# Mean genetic distance 1.620, standard deviation 0.470
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 4.029 sec (4.120 average)
#
#  ****** Running generation 3 ******
#
# Population's average fitness: 73.84000 stdev: 7.79066
# Best fitness: 99.00000 - size: (104, 786) - species 1 - id 165
# Average adjusted fitness: 0.281
# Mean genetic distance 1.591, standard deviation 0.451
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 3.851 sec (4.052 average)
#
#  ****** Running generation 4 ******
#
# Population's average fitness: 76.14000 stdev: 10.03396
# Best fitness: 105.00000 - size: (105, 782) - species 1 - id 231
# Average adjusted fitness: 0.296
# Mean genetic distance 1.436, standard deviation 0.197
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 3.859 sec (4.014 average)
#
#  ****** Running generation 5 ******
#
# Population's average fitness: 74.42000 stdev: 8.44770
# Best fitness: 97.00000 - size: (105, 782) - species 1 - id 231
# Average adjusted fitness: 0.294
# Mean genetic distance 1.491, standard deviation 0.203
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 3.901 sec (3.995 average)
#
#  ****** Running generation 6 ******
#
# Population's average fitness: 75.42000 stdev: 10.06398
# Best fitness: 108.00000 - size: (105, 782) - species 1 - id 231
# Average adjusted fitness: 0.224
# Mean genetic distance 1.428, standard deviation 0.157
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 3.806 sec (3.968 average)
#
#  ****** Running generation 7 ******
#
# Population's average fitness: 74.18000 stdev: 10.15616
# Best fitness: 112.00000 - size: (104, 576) - species 1 - id 352
# Average adjusted fitness: 0.244
# Mean genetic distance 1.548, standard deviation 0.165
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 3.749 sec (3.941 average)
#
#  ****** Running generation 8 ******
#
# Population's average fitness: 74.58000 stdev: 9.16753
# Best fitness: 104.00000 - size: (104, 570) - species 1 - id 391
# Average adjusted fitness: 0.264
# Mean genetic distance 1.444, standard deviation 0.240
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 3.013 sec (3.837 average)
#
#  ****** Running generation 9 ******
#
# Population's average fitness: 76.60000 stdev: 11.93650
# Best fitness: 109.00000 - size: (105, 769) - species 1 - id 430
# Average adjusted fitness: 0.325
# Mean genetic distance 1.297, standard deviation 0.301
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 3.299 sec (3.784 average)
#
#  ****** Running generation 10 ******
#
# Population's average fitness: 77.60000 stdev: 14.88892
# Best fitness: 131.00000 - size: (106, 756) - species 1 - id 495
# Average adjusted fitness: 0.215
# Mean genetic distance 1.457, standard deviation 0.228
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 3.481 sec (3.706 average)
#
#  ****** Running generation 11 ******
#
# Population's average fitness: 74.18000 stdev: 11.03937
# Best fitness: 112.00000 - size: (106, 756) - species 1 - id 495
# Average adjusted fitness: 0.228
# Mean genetic distance 1.523, standard deviation 0.227
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 2.746 sec (3.573 average)
#
#  ****** Running generation 12 ******
#
# Population's average fitness: 79.10000 stdev: 15.27252
# Best fitness: 128.00000 - size: (106, 573) - species 1 - id 614
# Average adjusted fitness: 0.248
# Mean genetic distance 1.567, standard deviation 0.175
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 2.768 sec (3.447 average)
#
#  ****** Running generation 13 ******
#
# Population's average fitness: 76.02000 stdev: 9.48576
# Best fitness: 97.00000 - size: (107, 573) - species 1 - id 673
# Average adjusted fitness: 0.401
# Mean genetic distance 1.507, standard deviation 0.161
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 2.862 sec (3.348 average)
#
#  ****** Running generation 14 ******
#
# Population's average fitness: 76.66000 stdev: 13.99516
# Best fitness: 153.00000 - size: (106, 570) - species 1 - id 677
# Average adjusted fitness: 0.161
# Mean genetic distance 1.556, standard deviation 0.183
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 3.000 sec (3.262 average)
#
#  ****** Running generation 15 ******
#
# Population's average fitness: 73.36000 stdev: 10.66913
# Best fitness: 103.00000 - size: (100, 5) - species 1 - id 725
# Average adjusted fitness: 0.277
# Mean genetic distance 1.651, standard deviation 0.169
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 2.157 sec (3.088 average)
#
#  ****** Running generation 16 ******
#
# Population's average fitness: 76.20000 stdev: 12.70118
# Best fitness: 109.00000 - size: (106, 559) - species 1 - id 775
# Average adjusted fitness: 0.302
# Mean genetic distance 1.628, standard deviation 0.262
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 1.686 sec (2.876 average)
#
#  ****** Running generation 17 ******
#
# Population's average fitness: 74.90000 stdev: 11.40745
# Best fitness: 117.00000 - size: (107, 566) - species 1 - id 839
# Average adjusted fitness: 0.248
# Mean genetic distance 1.704, standard deviation 0.265
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 2.434 sec (2.744 average)
#
#  ****** Running generation 18 ******
#
# Population's average fitness: 75.00000 stdev: 11.59655
# Best fitness: 113.00000 - size: (106, 558) - species 1 - id 912
# Average adjusted fitness: 0.269
# Mean genetic distance 1.742, standard deviation 0.224
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 2.535 sec (2.697 average)
#
#  ****** Running generation 19 ******
#
# Population's average fitness: 73.52000 stdev: 9.93426
# Best fitness: 104.00000 - size: (106, 555) - species 1 - id 933
# Average adjusted fitness: 0.257
# Mean genetic distance 1.779, standard deviation 0.235
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 2.388 sec (2.605 average)
#
#  ****** Running generation 20 ******
#
# Population's average fitness: 73.76000 stdev: 9.94899
# Best fitness: 107.00000 - size: (106, 546) - species 1 - id 964
# Average adjusted fitness: 0.277
# Mean genetic distance 1.748, standard deviation 0.219
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 2.306 sec (2.488 average)
#
#  ****** Running generation 21 ******
#
# Population's average fitness: 71.70000 stdev: 7.82113
# Best fitness: 91.00000 - size: (105, 379) - species 1 - id 1023
# Average adjusted fitness: 0.377
# Mean genetic distance 1.702, standard deviation 0.243
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 2.567 sec (2.470 average)
#
#  ****** Running generation 22 ******
#
# Population's average fitness: 73.40000 stdev: 10.31504
# Best fitness: 103.00000 - size: (105, 360) - species 1 - id 1082
# Average adjusted fitness: 0.312
# Mean genetic distance 1.475, standard deviation 0.247
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 2.488 sec (2.442 average)
#
#  ****** Running generation 23 ******
#
# Population's average fitness: 76.48000 stdev: 7.95045
# Best fitness: 96.00000 - size: (106, 367) - species 1 - id 1135
# Average adjusted fitness: 0.390
# Mean genetic distance 1.616, standard deviation 0.208
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 2.305 sec (2.386 average)
#
#  ****** Running generation 24 ******
# Population's average fitness: 73.44000 stdev: 9.32987
# Best fitness: 109.00000 - size: (106, 538) - species 1 - id 1190
# Average adjusted fitness: 0.274
# Mean genetic distance 1.648, standard deviation 0.222
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 1.976 sec (2.284 average)
#
#  ****** Running generation 25 ******
#
# Population's average fitness: 75.04000 stdev: 12.00993
# Best fitness: 125.00000 - size: (107, 538) - species 1 - id 1213
# Average adjusted fitness: 0.207
# Mean genetic distance 1.588, standard deviation 0.179
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 1.721 sec (2.240 average)
#
#  ****** Running generation 26 ******
#
# Population's average fitness: 73.78000 stdev: 12.78169
# Best fitness: 132.00000 - size: (107, 537) - species 1 - id 1298
# Average adjusted fitness: 0.180
# Mean genetic distance 1.694, standard deviation 0.162
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 1.959 sec (2.268 average)
#
#  ****** Running generation 27 ******
#
# Population's average fitness: 75.92000 stdev: 11.25849
# Best fitness: 112.00000 - size: (104, 519) - species 1 - id 1326
# Average adjusted fitness: 0.264
# Mean genetic distance 1.686, standard deviation 0.183
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 2.299 sec (2.254 average)
#
#  ****** Running generation 28 ******
#
# Population's average fitness: 74.48000 stdev: 9.64000
# Best fitness: 107.00000 - size: (104, 354) - species 1 - id 1380
# Average adjusted fitness: 0.277
# Mean genetic distance 1.711, standard deviation 0.430
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 2.716 sec (2.272 average)
#
#  ****** Running generation 29 ******
#
# Population's average fitness: 74.88000 stdev: 9.38859
# Best fitness: 95.00000 - size: (104, 355) - species 1 - id 1419
# Average adjusted fitness: 0.390
# Mean genetic distance 1.781, standard deviation 0.318
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 2.142 sec (2.248 average)
#
#  ****** Running generation 30 ******
#
# Population's average fitness: 73.06000 stdev: 10.69656
# Best fitness: 103.00000 - size: (105, 179) - species 1 - id 1464
# Average adjusted fitness: 0.270
# Mean genetic distance 1.663, standard deviation 0.158
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 2.315 sec (2.249 average)
#
#  ****** Running generation 31 ******
#
# Population's average fitness: 72.36000 stdev: 9.67835
# Best fitness: 105.00000 - size: (106, 512) - species 1 - id 1498
# Average adjusted fitness: 0.223
# Mean genetic distance 1.699, standard deviation 0.162
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 2.181 sec (2.210 average)
#
#  ****** Running generation 32 ******
#
# Population's average fitness: 74.46000 stdev: 10.72979
# Best fitness: 113.00000 - size: (105, 514) - species 1 - id 1564
# Average adjusted fitness: 0.229
# Mean genetic distance 1.693, standard deviation 0.179
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 2.763 sec (2.238 average)
#
#  ****** Running generation 33 ******
#
# Population's average fitness: 75.96000 stdev: 11.38237
# Best fitness: 108.00000 - size: (106, 337) - species 1 - id 1624
# Average adjusted fitness: 0.288
# Mean genetic distance 1.680, standard deviation 0.234
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 2.416 sec (2.249 average)
#
#  ****** Running generation 34 ******
#
# Population's average fitness: 75.84000 stdev: 9.20078
# Best fitness: 99.00000 - size: (105, 507) - species 1 - id 1637
# Average adjusted fitness: 0.374
# Mean genetic distance 1.720, standard deviation 0.256
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 2.176 sec (2.269 average)
#
#  ****** Running generation 35 ******
#
# Population's average fitness: 73.52000 stdev: 9.21790
# Best fitness: 102.00000 - size: (106, 511) - species 1 - id 1715
# Average adjusted fitness: 0.270
# Mean genetic distance 1.736, standard deviation 0.264
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 2.212 sec (2.318 average)
#
#  ****** Running generation 36 ******
#
# Population's average fitness: 72.92000 stdev: 8.74721
# Best fitness: 104.00000 - size: (106, 502) - species 1 - id 1762
# Average adjusted fitness: 0.260
# Mean genetic distance 1.792, standard deviation 0.232
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 2.388 sec (2.361 average)
#
#  ****** Running generation 37 ******
#
# Population's average fitness: 73.14000 stdev: 9.71187
# Best fitness: 103.00000 - size: (105, 169) - species 1 - id 1820
# Average adjusted fitness: 0.272
# Mean genetic distance 1.637, standard deviation 0.280
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 2.202 sec (2.351 average)
#
#  ****** Running generation 38 ******
#
# Population's average fitness: 76.24000 stdev: 9.47536
# Best fitness: 104.00000 - size: (106, 506) - species 1 - id 1836
# Average adjusted fitness: 0.323
# Mean genetic distance 1.718, standard deviation 0.371
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 1.896 sec (2.269 average)
#
#  ****** Running generation 39 ******
#
# Population's average fitness: 72.86000 stdev: 9.54570
# Best fitness: 116.00000 - size: (106, 493) - species 1 - id 1878
# Average adjusted fitness: 0.201
# Mean genetic distance 1.517, standard deviation 0.407
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 2.339 sec (2.289 average)
#
#  ****** Running generation 40 ******
#
# Population's average fitness: 71.56000 stdev: 7.56614
# Best fitness: 95.00000 - size: (106, 492) - species 1 - id 1964
# Average adjusted fitness: 0.311
# Mean genetic distance 1.667, standard deviation 0.196
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 2.315 sec (2.289 average)
#
#  ****** Running generation 41 ******
#
# Population's average fitness: 76.60000 stdev: 11.36662
# Best fitness: 109.00000 - size: (104, 498) - species 1 - id 1988
# Average adjusted fitness: 0.280
# Mean genetic distance 1.773, standard deviation 0.207
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 2.452 sec (2.316 average)
#
#  ****** Running generation 42 ******
#
# Population's average fitness: 76.42000 stdev: 10.61714
# Best fitness: 110.00000 - size: (104, 491) - species 1 - id 2031
# Average adjusted fitness: 0.270
# Mean genetic distance 1.774, standard deviation 0.163
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 2.659 sec (2.305 average)
#
#  ****** Running generation 43 ******
#
# Population's average fitness: 74.46000 stdev: 9.94024
# Best fitness: 111.00000 - size: (104, 494) - species 1 - id 2107
# Average adjusted fitness: 0.239
# Mean genetic distance 1.690, standard deviation 0.295
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 2.691 sec (2.333 average)
#
#  ****** Running generation 44 ******
#
# Population's average fitness: 73.98000 stdev: 10.97176
# Best fitness: 112.00000 - size: (103, 338) - species 1 - id 2125
# Average adjusted fitness: 0.224
# Mean genetic distance 1.538, standard deviation 0.125
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 2.591 sec (2.374 average)
#
#  ****** Running generation 45 ******
#
# Population's average fitness: 76.56000 stdev: 10.82434
# Best fitness: 108.00000 - size: (103, 325) - species 1 - id 2199
# Average adjusted fitness: 0.301
# Mean genetic distance 1.489, standard deviation 0.141
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 2.391 sec (2.392 average)
#
#  ****** Running generation 46 ******
#
# Population's average fitness: 76.14000 stdev: 13.63380
# Best fitness: 129.00000 - size: (105, 492) - species 1 - id 2255
# Average adjusted fitness: 0.187
# Mean genetic distance 1.470, standard deviation 0.214
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 2.290 sec (2.382 average)
#
#  ****** Running generation 47 ******
#
# Population's average fitness: 75.92000 stdev: 11.91779
# Best fitness: 111.00000 - size: (103, 321) - species 1 - id 2278
# Average adjusted fitness: 0.254
# Mean genetic distance 1.564, standard deviation 0.260
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 2.386 sec (2.401 average)
#
#  ****** Running generation 48 ******
# Population's average fitness: 72.92000 stdev: 7.29614
# Best fitness: 94.00000 - size: (105, 485) - species 1 - id 2320
# Average adjusted fitness: 0.297
# Mean genetic distance 1.650, standard deviation 0.221
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 2.163 sec (2.427 average)
#
#  ****** Running generation 49 ******
#
# Population's average fitness: 74.46000 stdev: 10.92925
# Best fitness: 113.00000 - size: (104, 473) - species 1 - id 2370
# Average adjusted fitness: 0.213
# Mean genetic distance 1.624, standard deviation 0.293
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 2.524 sec (2.446 average)
#
#  ****** Running generation 50 ******
#
# Population's average fitness: 77.74000 stdev: 13.07794
# Best fitness: 126.00000 - size: (103, 315) - species 1 - id 2425
# Average adjusted fitness: 0.222
# Mean genetic distance 1.749, standard deviation 0.259
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 2.418 sec (2.456 average)
#
#  ****** Running generation 51 ******
#
# Population's average fitness: 76.32000 stdev: 11.12374
# Best fitness: 107.00000 - size: (102, 310) - species 1 - id 2474
# Average adjusted fitness: 0.287
# Mean genetic distance 1.870, standard deviation 0.352
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 2.212 sec (2.432 average)
#
#  ****** Running generation 52 ******
#
# Population's average fitness: 75.92000 stdev: 11.67877
# Best fitness: 112.00000 - size: (104, 312) - species 1 - id 2540
# Average adjusted fitness: 0.248
# Mean genetic distance 2.000, standard deviation 0.391
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 1.821 sec (2.349 average)
#
#  ****** Running generation 53 ******
#
# Population's average fitness: 74.14000 stdev: 9.37445
# Best fitness: 98.00000 - size: (104, 318) - species 1 - id 2594
# Average adjusted fitness: 0.318
# Mean genetic distance 1.851, standard deviation 0.368
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 1.872 sec (2.267 average)
#
#  ****** Running generation 54 ******
#
# Population's average fitness: 77.20000 stdev: 11.35429
# Best fitness: 113.00000 - size: (102, 301) - species 1 - id 2626
# Average adjusted fitness: 0.284
# Mean genetic distance 1.757, standard deviation 0.348
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 1.651 sec (2.173 average)
#
#  ****** Running generation 55 ******
#
# Population's average fitness: 75.84000 stdev: 10.67588
# Best fitness: 105.00000 - size: (106, 321) - species 1 - id 2681
# Average adjusted fitness: 0.306
# Mean genetic distance 1.780, standard deviation 0.272
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 1.706 sec (2.104 average)
#
#  ****** Running generation 56 ******
#
# Population's average fitness: 75.26000 stdev: 12.66935
# Best fitness: 130.00000 - size: (103, 172) - species 1 - id 2729
# Average adjusted fitness: 0.183
# Mean genetic distance 1.796, standard deviation 0.347
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 1.709 sec (2.046 average)
#
#  ****** Running generation 57 ******
#
# Population's average fitness: 74.36000 stdev: 11.47826
# Best fitness: 114.00000 - size: (107, 325) - species 1 - id 2786
# Average adjusted fitness: 0.223
# Mean genetic distance 1.637, standard deviation 0.358
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 1.648 sec (1.973 average)
#
#  ****** Running generation 58 ******
#
# Population's average fitness: 75.74000 stdev: 13.62470
# Best fitness: 121.00000 - size: (102, 16) - species 1 - id 2790
# Average adjusted fitness: 0.246
# Mean genetic distance 1.662, standard deviation 0.285
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 1.358 sec (1.892 average)
#
#  ****** Running generation 59 ******
#
# Population's average fitness: 76.90000 stdev: 13.62681
# Best fitness: 108.00000 - size: (105, 161) - species 1 - id 2847
# Average adjusted fitness: 0.338
# Mean genetic distance 1.751, standard deviation 0.188
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.817 sec (1.721 average)
#
#  ****** Running generation 60 ******
#
# Population's average fitness: 75.00000 stdev: 11.52042
# Best fitness: 106.00000 - size: (102, 16) - species 1 - id 2907
# Average adjusted fitness: 0.311
# Mean genetic distance 1.730, standard deviation 0.190
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.865 sec (1.566 average)
#
#  ****** Running generation 61 ******
#
# Population's average fitness: 75.58000 stdev: 10.64911
# Best fitness: 101.00000 - size: (104, 162) - species 1 - id 2968
# Average adjusted fitness: 0.348
# Mean genetic distance 1.640, standard deviation 0.229
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.656 sec (1.411 average)
#
#  ****** Running generation 62 ******
#
# Population's average fitness: 71.66000 stdev: 9.05894
# Best fitness: 105.00000 - size: (104, 162) - species 1 - id 2968
# Average adjusted fitness: 0.225
# Mean genetic distance 1.572, standard deviation 0.284
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.605 sec (1.289 average)
#
#  ****** Running generation 63 ******
#
# Population's average fitness: 73.12000 stdev: 9.99928
# Best fitness: 107.00000 - size: (101, 13) - species 1 - id 3034
# Average adjusted fitness: 0.263
# Mean genetic distance 1.592, standard deviation 0.292
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.606 sec (1.162 average)
#
#  ****** Running generation 64 ******
#
# Population's average fitness: 74.62000 stdev: 8.34479
# Best fitness: 91.00000 - size: (100, 17) - species 1 - id 3076
# Average adjusted fitness: 0.415
# Mean genetic distance 1.641, standard deviation 0.290
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.679 sec (1.065 average)
#
#  ****** Running generation 65 ******
#
# Population's average fitness: 72.46000 stdev: 8.69991
# Best fitness: 91.00000 - size: (100, 12) - species 1 - id 3154
# Average adjusted fitness: 0.338
# Mean genetic distance 1.715, standard deviation 0.221
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.647 sec (0.959 average)
#
#  ****** Running generation 66 ******
#
# Population's average fitness: 71.58000 stdev: 7.57652
# Best fitness: 95.00000 - size: (100, 13) - species 1 - id 3188
# Average adjusted fitness: 0.268
# Mean genetic distance 1.614, standard deviation 0.370
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.541 sec (0.842 average)
#
#  ****** Running generation 67 ******
#
# Population's average fitness: 74.14000 stdev: 10.91789
# Best fitness: 104.00000 - size: (100, 14) - species 1 - id 3240
# Average adjusted fitness: 0.272
# Mean genetic distance 1.383, standard deviation 0.506
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.630 sec (0.741 average)
#
#  ****** Running generation 68 ******
#
# Population's average fitness: 74.22000 stdev: 11.25929
# Best fitness: 109.00000 - size: (105, 163) - species 1 - id 3187
# Average adjusted fitness: 0.260
# Mean genetic distance 1.499, standard deviation 0.437
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.744 sec (0.679 average)
#
#  ****** Running generation 69 ******
#
# Population's average fitness: 75.06000 stdev: 11.09668
# Best fitness: 105.00000 - size: (100, 12) - species 1 - id 3345
# Average adjusted fitness: 0.287
# Mean genetic distance 1.605, standard deviation 0.264
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.670 sec (0.664 average)
#
#  ****** Running generation 70 ******
#
# Population's average fitness: 74.16000 stdev: 10.60068
# Best fitness: 109.00000 - size: (100, 8) - species 1 - id 3393
# Average adjusted fitness: 0.243
# Mean genetic distance 1.703, standard deviation 0.166
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.656 sec (0.644 average)
#
#  ****** Running generation 71 ******
#
# Population's average fitness: 75.16000 stdev: 9.62779
# Best fitness: 111.00000 - size: (106, 161) - species 1 - id 3427
# Average adjusted fitness: 0.253
# Mean genetic distance 1.584, standard deviation 0.351
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.532 sec (0.631 average)
#
#  ****** Running generation 72 ******
#
# Population's average fitness: 76.44000 stdev: 13.17142
# Best fitness: 125.00000 - size: (106, 161) - species 1 - id 3427
# Average adjusted fitness: 0.217
# Mean genetic distance 1.299, standard deviation 0.474
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.662 sec (0.637 average)
#
#  ****** Running generation 73 ******
#
# Population's average fitness: 72.88000 stdev: 11.13668
# Best fitness: 121.00000 - size: (100, 11) - species 1 - id 3518
# Average adjusted fitness: 0.170
# Mean genetic distance 1.519, standard deviation 0.280
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.878 sec (0.664 average)
#
#  ****** Running generation 74 ******
#
# Population's average fitness: 73.48000 stdev: 10.10988
# Best fitness: 103.00000 - size: (106, 158) - species 1 - id 3568
# Average adjusted fitness: 0.262
# Mean genetic distance 1.498, standard deviation 0.374
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.733 sec (0.669 average)
#
#  ****** Running generation 75 ******
#
# Population's average fitness: 73.70000 stdev: 10.48857
# Best fitness: 106.00000 - size: (101, 11) - species 1 - id 3627
# Average adjusted fitness: 0.249
# Mean genetic distance 1.494, standard deviation 0.341
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.763 sec (0.681 average)
#
#  ****** Running generation 76 ******
#
# Population's average fitness: 75.40000 stdev: 14.58218
# Best fitness: 119.00000 - size: (101, 12) - species 1 - id 3666
# Average adjusted fitness: 0.235
# Mean genetic distance 1.731, standard deviation 0.187
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.830 sec (0.710 average)
#
#  ****** Running generation 77 ******
#
# Population's average fitness: 75.12000 stdev: 11.60627
# Best fitness: 115.00000 - size: (106, 156) - species 1 - id 3718
# Average adjusted fitness: 0.261
# Mean genetic distance 1.670, standard deviation 0.347
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.537 sec (0.701 average)
#
#  ****** Running generation 78 ******
#
# Population's average fitness: 78.18000 stdev: 12.11559
# Best fitness: 109.00000 - size: (105, 154) - species 1 - id 3782
# Average adjusted fitness: 0.330
# Mean genetic distance 1.556, standard deviation 0.338
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.593 sec (0.686 average)
#
#  ****** Running generation 79 ******
#
# Population's average fitness: 73.94000 stdev: 9.92252
# Best fitness: 108.00000 - size: (105, 152) - species 1 - id 3809
# Average adjusted fitness: 0.275
# Mean genetic distance 1.640, standard deviation 0.306
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.809 sec (0.699 average)
#
#  ****** Running generation 80 ******
#
# Population's average fitness: 74.46000 stdev: 12.44542
# Best fitness: 125.00000 - size: (103, 14) - species 1 - id 3871
# Average adjusted fitness: 0.185
# Mean genetic distance 1.902, standard deviation 0.239
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.818 sec (0.716 average)
#
#  ****** Running generation 81 ******
#
# Population's average fitness: 72.06000 stdev: 8.56600
# Best fitness: 92.00000 - size: (104, 16) - species 1 - id 3903
# Average adjusted fitness: 0.312
# Mean genetic distance 1.926, standard deviation 0.362
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.491 sec (0.712 average)
#
#  ****** Running generation 82 ******
#
# Population's average fitness: 77.02000 stdev: 14.29194
# Best fitness: 127.00000 - size: (104, 16) - species 1 - id 3956
# Average adjusted fitness: 0.219
# Mean genetic distance 1.987, standard deviation 0.351
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.428 sec (0.688 average)
#
#  ****** Running generation 83 ******
#
# Population's average fitness: 70.58000 stdev: 8.27790
# Best fitness: 104.00000 - size: (103, 14) - species 1 - id 4001
# Average adjusted fitness: 0.223
# Mean genetic distance 2.094, standard deviation 0.365
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.454 sec (0.646 average)
#
#  ****** Running generation 84 ******
#
# Population's average fitness: 73.06000 stdev: 9.81103
# Best fitness: 108.00000 - size: (103, 15) - species 1 - id 4057
# Average adjusted fitness: 0.224
# Mean genetic distance 2.228, standard deviation 0.358
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.445 sec (0.617 average)
#
#  ****** Running generation 85 ******
#
# Population's average fitness: 74.16000 stdev: 11.39186
# Best fitness: 125.00000 - size: (101, 9) - species 1 - id 4114
# Average adjusted fitness: 0.180
# Mean genetic distance 2.421, standard deviation 0.283
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.436 sec (0.584 average)
#
#  ****** Running generation 86 ******
#
# Population's average fitness: 73.98000 stdev: 9.52573
# Best fitness: 103.00000 - size: (101, 8) - species 1 - id 4176
# Average adjusted fitness: 0.275
# Mean genetic distance 2.146, standard deviation 0.433
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.429 sec (0.544 average)
#
#  ****** Running generation 87 ******
#
# Population's average fitness: 75.46000 stdev: 15.22920
# Best fitness: 130.00000 - size: (103, 14) - species 1 - id 4206
# Average adjusted fitness: 0.186
# Mean genetic distance 2.043, standard deviation 0.199
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.424 sec (0.533 average)
#
#  ****** Running generation 88 ******
#
# Population's average fitness: 76.44000 stdev: 13.88547
# Best fitness: 129.00000 - size: (103, 15) - species 1 - id 4242
# Average adjusted fitness: 0.204
# Mean genetic distance 2.017, standard deviation 0.335
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.422 sec (0.516 average)
#
#  ****** Running generation 89 ******
#
# Population's average fitness: 72.86000 stdev: 9.32097
# Best fitness: 95.00000 - size: (103, 14) - species 1 - id 4291
# Average adjusted fitness: 0.308
# Mean genetic distance 2.013, standard deviation 0.232
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.484 sec (0.483 average)
#
#  ****** Running generation 90 ******
#
# Population's average fitness: 78.06000 stdev: 13.99487
# Best fitness: 132.00000 - size: (104, 15) - species 1 - id 4335
# Average adjusted fitness: 0.218
# Mean genetic distance 1.923, standard deviation 0.221
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.419 sec (0.443 average)
#
#  ****** Running generation 91 ******
#
# Population's average fitness: 79.84000 stdev: 14.11150
# Best fitness: 117.00000 - size: (103, 14) - species 1 - id 4410
# Average adjusted fitness: 0.312
# Mean genetic distance 1.917, standard deviation 0.264
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.410 sec (0.435 average)
#
#  ****** Running generation 92 ******
#
# Population's average fitness: 76.34000 stdev: 13.21001
# Best fitness: 113.00000 - size: (105, 17) - species 1 - id 4451
# Average adjusted fitness: 0.267
# Mean genetic distance 1.897, standard deviation 0.278
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.411 sec (0.433 average)
#
#  ****** Running generation 93 ******
#
# Population's average fitness: 74.26000 stdev: 10.38424
# Best fitness: 102.00000 - size: (104, 15) - species 1 - id 4487
# Average adjusted fitness: 0.289
# Mean genetic distance 1.509, standard deviation 0.381
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.400 sec (0.428 average)
#
#  ****** Running generation 94 ******
#
# Population's average fitness: 72.90000 stdev: 9.56086
# Best fitness: 104.00000 - size: (103, 12) - species 1 - id 4549
# Average adjusted fitness: 0.241
# Mean genetic distance 1.502, standard deviation 0.269
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.398 sec (0.423 average)
#
#  ****** Running generation 95 ******
#
# Population's average fitness: 74.72000 stdev: 11.32085
# Best fitness: 125.00000 - size: (103, 13) - species 1 - id 4579
# Average adjusted fitness: 0.176
# Mean genetic distance 1.516, standard deviation 0.239
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.388 sec (0.419 average)
#
#  ****** Running generation 96 ******
#
# Population's average fitness: 72.46000 stdev: 8.87966
# Best fitness: 101.00000 - size: (103, 12) - species 1 - id 4625
# Average adjusted fitness: 0.249
# Mean genetic distance 1.531, standard deviation 0.210
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.444 sec (0.420 average)
#
#  ****** Running generation 97 ******
#
# Population's average fitness: 71.28000 stdev: 9.20226
# Best fitness: 114.00000 - size: (104, 13) - species 1 - id 4667
# Average adjusted fitness: 0.194
# Mean genetic distance 1.649, standard deviation 0.195
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.399 sec (0.418 average)
#
#  ****** Running generation 98 ******
#
# Population's average fitness: 74.06000 stdev: 9.05187
# Best fitness: 101.00000 - size: (103, 15) - species 1 - id 4736
# Average adjusted fitness: 0.291
# Mean genetic distance 1.708, standard deviation 0.207
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.409 sec (0.416 average)
#
#  ****** Running generation 99 ******
#
# Population's average fitness: 76.94000 stdev: 12.09365
# Best fitness: 116.00000 - size: (104, 14) - species 1 - id 4796
# Average adjusted fitness: 0.263
# Mean genetic distance 1.800, standard deviation 0.296
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.393 sec (0.407 average)
#
#  ****** Running generation 100 ******
#
# Population's average fitness: 73.60000 stdev: 11.06888
# Best fitness: 107.00000 - size: (104, 12) - species 1 - id 4824
# Average adjusted fitness: 0.241
# Mean genetic distance 1.679, standard deviation 0.323
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.408 sec (0.406 average)
#
#  ****** Running generation 101 ******
#
# Population's average fitness: 72.48000 stdev: 10.06825
# Best fitness: 103.00000 - size: (104, 14) - species 1 - id 4893
# Average adjusted fitness: 0.256
# Mean genetic distance 1.542, standard deviation 0.314
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.408 sec (0.406 average)
#
#  ****** Running generation 102 ******
#
# Population's average fitness: 73.24000 stdev: 9.32000
# Best fitness: 101.00000 - size: (104, 12) - species 1 - id 4919
# Average adjusted fitness: 0.269
# Mean genetic distance 1.603, standard deviation 0.260
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.400 sec (0.405 average)
#
#  ****** Running generation 103 ******
#
# Population's average fitness: 73.08000 stdev: 9.79967
# Best fitness: 104.00000 - size: (104, 12) - species 1 - id 4919
# Average adjusted fitness: 0.246
# Mean genetic distance 1.632, standard deviation 0.328
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.405 sec (0.405 average)
#
#  ****** Running generation 104 ******
#
# Population's average fitness: 73.96000 stdev: 11.27645
# Best fitness: 115.00000 - size: (104, 10) - species 1 - id 4997
# Average adjusted fitness: 0.211
# Mean genetic distance 1.778, standard deviation 0.249
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.453 sec (0.411 average)
#
#  ****** Running generation 105 ******
#
# Population's average fitness: 75.86000 stdev: 11.69617
# Best fitness: 109.00000 - size: (103, 10) - species 1 - id 5060
# Average adjusted fitness: 0.280
# Mean genetic distance 1.761, standard deviation 0.200
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.389 sec (0.411 average)
#
#  ****** Running generation 106 ******
#
# Population's average fitness: 71.50000 stdev: 9.95640
# Best fitness: 105.00000 - size: (104, 11) - species 1 - id 5117
# Average adjusted fitness: 0.202
# Mean genetic distance 1.718, standard deviation 0.178
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.399 sec (0.406 average)
#
#  ****** Running generation 107 ******
#
# Population's average fitness: 73.06000 stdev: 9.78859
# Best fitness: 109.00000 - size: (101, 8) - species 1 - id 5177
# Average adjusted fitness: 0.219
# Mean genetic distance 1.808, standard deviation 0.152
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.398 sec (0.406 average)
#
#  ****** Running generation 108 ******
#
# Population's average fitness: 72.96000 stdev: 8.66939
# Best fitness: 95.00000 - size: (102, 10) - species 1 - id 5224
# Average adjusted fitness: 0.311
# Mean genetic distance 1.681, standard deviation 0.229
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.395 sec (0.405 average)
#
#  ****** Running generation 109 ******
#
# Population's average fitness: 75.26000 stdev: 15.52779
# Best fitness: 144.00000 - size: (101, 7) - species 1 - id 5272
# Average adjusted fitness: 0.151
# Mean genetic distance 1.507, standard deviation 0.210
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.382 sec (0.404 average)
#
#  ****** Running generation 110 ******
#
# Population's average fitness: 71.88000 stdev: 7.37195
# Best fitness: 89.00000 - size: (100, 7) - species 1 - id 5300
# Average adjusted fitness: 0.342
# Mean genetic distance 1.474, standard deviation 0.217
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.393 sec (0.402 average)
#
#  ****** Running generation 111 ******
#
# Population's average fitness: 71.22000 stdev: 9.75764
# Best fitness: 105.00000 - size: (101, 8) - species 1 - id 5331
# Average adjusted fitness: 0.196
# Mean genetic distance 1.581, standard deviation 0.225
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.386 sec (0.400 average)
#
#  ****** Running generation 112 ******
#
# Population's average fitness: 73.52000 stdev: 9.44085
# Best fitness: 97.00000 - size: (101, 9) - species 1 - id 5404
# Average adjusted fitness: 0.309
# Mean genetic distance 1.760, standard deviation 0.223
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.372 sec (0.397 average)
#
#  ****** Running generation 113 ******
#
# Population's average fitness: 74.64000 stdev: 13.81414
# Best fitness: 129.00000 - size: (101, 7) - species 1 - id 5464
# Average adjusted fitness: 0.201
# Mean genetic distance 1.658, standard deviation 0.252
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.425 sec (0.399 average)
#
#  ****** Running generation 114 ******
#
# Population's average fitness: 71.80000 stdev: 8.72697
# Best fitness: 102.00000 - size: (100, 5) - species 1 - id 5490
# Average adjusted fitness: 0.226
# Mean genetic distance 1.624, standard deviation 0.261
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.378 sec (0.392 average)
#
#  ****** Running generation 115 ******
#
# Population's average fitness: 70.52000 stdev: 8.34563
# Best fitness: 102.00000 - size: (102, 9) - species 1 - id 5524
# Average adjusted fitness: 0.213
# Mean genetic distance 1.541, standard deviation 0.335
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.371 sec (0.390 average)
#
#  ****** Running generation 116 ******
#
# Population's average fitness: 75.58000 stdev: 12.92144
# Best fitness: 140.00000 - size: (103, 10) - species 1 - id 5612
# Average adjusted fitness: 0.174
# Mean genetic distance 1.675, standard deviation 0.232
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.367 sec (0.387 average)
#
#  ****** Running generation 117 ******
#
# Population's average fitness: 75.40000 stdev: 12.10785
# Best fitness: 110.00000 - size: (102, 10) - species 1 - id 5663
# Average adjusted fitness: 0.264
# Mean genetic distance 1.841, standard deviation 0.224
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.369 sec (0.384 average)
#
#  ****** Running generation 118 ******
#
# Population's average fitness: 74.16000 stdev: 11.47930
# Best fitness: 119.00000 - size: (103, 10) - species 1 - id 5698
# Average adjusted fitness: 0.199
# Mean genetic distance 1.918, standard deviation 0.225
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.361 sec (0.380 average)
#
#  ****** Running generation 119 ******
#
# Population's average fitness: 72.22000 stdev: 9.31727
# Best fitness: 99.00000 - size: (101, 7) - species 1 - id 5745
# Average adjusted fitness: 0.276
# Mean genetic distance 1.933, standard deviation 0.280
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.357 sec (0.378 average)
#
#  ****** Running generation 120 ******
#
# Population's average fitness: 71.68000 stdev: 8.38914
# Best fitness: 95.00000 - size: (101, 7) - species 1 - id 5800
# Average adjusted fitness: 0.271
# Mean genetic distance 2.078, standard deviation 0.301
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.365 sec (0.375 average)
#
#  ****** Running generation 121 ******
#
# Population's average fitness: 73.78000 stdev: 9.85351
# Best fitness: 97.00000 - size: (101, 8) - species 1 - id 5841
# Average adjusted fitness: 0.317
# Mean genetic distance 2.116, standard deviation 0.248
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.353 sec (0.372 average)
#
#  ****** Running generation 122 ******
#
# Population's average fitness: 74.28000 stdev: 12.56987
# Best fitness: 113.00000 - size: (102, 9) - species 1 - id 5867
# Average adjusted fitness: 0.226
# Mean genetic distance 1.988, standard deviation 0.382
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.411 sec (0.376 average)
#
#  ****** Running generation 123 ******
#
# Population's average fitness: 71.06000 stdev: 7.90547
# Best fitness: 91.00000 - size: (103, 7) - species 1 - id 5928
# Average adjusted fitness: 0.288
# Mean genetic distance 1.833, standard deviation 0.274
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.372 sec (0.370 average)
#
#  ****** Running generation 124 ******
#
# Population's average fitness: 72.08000 stdev: 9.94553
# Best fitness: 107.00000 - size: (103, 7) - species 1 - id 5928
# Average adjusted fitness: 0.206
# Mean genetic distance 2.009, standard deviation 0.243
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.368 sec (0.369 average)
#
#  ****** Running generation 125 ******
#
# Population's average fitness: 73.24000 stdev: 10.13225
# Best fitness: 97.00000 - size: (103, 7) - species 1 - id 6008
# Average adjusted fitness: 0.301
# Mean genetic distance 1.959, standard deviation 0.333
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.358 sec (0.368 average)
#
#  ****** Running generation 126 ******
#
# Population's average fitness: 72.68000 stdev: 10.68165
# Best fitness: 103.00000 - size: (103, 6) - species 1 - id 6060
# Average adjusted fitness: 0.260
# Mean genetic distance 1.689, standard deviation 0.239
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.355 sec (0.367 average)
#
#  ****** Running generation 127 ******
#
# Population's average fitness: 71.58000 stdev: 9.86933
# Best fitness: 118.00000 - size: (102, 9) - species 1 - id 6133
# Average adjusted fitness: 0.156
# Mean genetic distance 1.650, standard deviation 0.229
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.358 sec (0.366 average)
#
#  ****** Running generation 128 ******
#
# Population's average fitness: 73.52000 stdev: 11.62625
# Best fitness: 112.00000 - size: (101, 8) - species 1 - id 6169
# Average adjusted fitness: 0.230
# Mean genetic distance 1.887, standard deviation 0.293
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.356 sec (0.365 average)
#
#  ****** Running generation 129 ******
#
# Population's average fitness: 74.36000 stdev: 12.49441
# Best fitness: 127.00000 - size: (102, 7) - species 1 - id 6222
# Average adjusted fitness: 0.190
# Mean genetic distance 1.862, standard deviation 0.345
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.365 sec (0.366 average)
#
#  ****** Running generation 130 ******
#
# Population's average fitness: 72.18000 stdev: 9.11853
# Best fitness: 104.00000 - size: (102, 5) - species 1 - id 6264
# Average adjusted fitness: 0.224
# Mean genetic distance 1.988, standard deviation 0.404
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.419 sec (0.372 average)
#
#  ****** Running generation 131 ******
#
# Population's average fitness: 72.50000 stdev: 9.21792
# Best fitness: 108.00000 - size: (102, 7) - species 1 - id 6306
# Average adjusted fitness: 0.211
# Mean genetic distance 1.955, standard deviation 0.556
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.356 sec (0.372 average)
#
#  ****** Running generation 132 ******
#
# Population's average fitness: 75.20000 stdev: 11.88108
# Best fitness: 111.00000 - size: (102, 6) - species 1 - id 6377
# Average adjusted fitness: 0.254
# Mean genetic distance 1.861, standard deviation 0.412
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.347 sec (0.365 average)
#
#  ****** Running generation 133 ******
#
# Population's average fitness: 74.20000 stdev: 12.40806
# Best fitness: 111.00000 - size: (100, 3) - species 1 - id 6393
# Average adjusted fitness: 0.233
# Mean genetic distance 1.888, standard deviation 0.366
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.347 sec (0.363 average)
#
#  ****** Running generation 134 ******
#
# Population's average fitness: 77.58000 stdev: 14.93331
# Best fitness: 133.00000 - size: (102, 5) - species 1 - id 6442
# Average adjusted fitness: 0.208
# Mean genetic distance 1.993, standard deviation 0.354
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.333 sec (0.359 average)
#
#  ****** Running generation 135 ******
#
# Population's average fitness: 70.44000 stdev: 7.79015
# Best fitness: 96.00000 - size: (103, 6) - species 1 - id 6525
# Average adjusted fitness: 0.270
# Mean genetic distance 2.108, standard deviation 0.327
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.340 sec (0.358 average)
#
#  ****** Running generation 136 ******
#
# Population's average fitness: 74.54000 stdev: 12.44381
# Best fitness: 112.00000 - size: (103, 6) - species 1 - id 6537
# Average adjusted fitness: 0.236
# Mean genetic distance 2.212, standard deviation 0.273
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.345 sec (0.357 average)
#
#  ****** Running generation 137 ******
#
# Population's average fitness: 74.96000 stdev: 11.83040
# Best fitness: 110.00000 - size: (102, 2) - species 1 - id 6624
# Average adjusted fitness: 0.270
# Mean genetic distance 2.192, standard deviation 0.460
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.399 sec (0.361 average)
#
#  ****** Running generation 138 ******
#
# Population's average fitness: 71.28000 stdev: 8.78189
# Best fitness: 103.00000 - size: (103, 6) - species 1 - id 6641
# ...
# Best fitness: 107.00000 - size: (103, 3) - species 1 - id 8811
# Average adjusted fitness: 0.273
# Mean genetic distance 1.820, standard deviation 0.296
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.316 sec (0.331 average)
#
#  ****** Running generation 184 ******
#
# Population's average fitness: 73.88000 stdev: 12.32987
# Best fitness: 105.00000 - size: (102, 1) - species 1 - id 8838
# Average adjusted fitness: 0.293
# Mean genetic distance 1.950, standard deviation 0.413
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.320 sec (0.326 average)
#
#  ****** Running generation 185 ******
#
# Population's average fitness: 70.46000 stdev: 7.80566
# Best fitness: 99.00000 - size: (103, 3) - species 1 - id 8894
# Average adjusted fitness: 0.249
# Mean genetic distance 1.999, standard deviation 0.444
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.326 sec (0.328 average)
#
#  ****** Running generation 186 ******
#
# Population's average fitness: 71.90000 stdev: 11.28760
# Best fitness: 107.00000 - size: (103, 2) - species 1 - id 8941
# Average adjusted fitness: 0.253
# Mean genetic distance 2.109, standard deviation 0.341
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.320 sec (0.329 average)
#
#  ****** Running generation 187 ******
#
# Population's average fitness: 71.96000 stdev: 10.50516
# Best fitness: 105.00000 - size: (101, 1) - species 1 - id 9011
# Average adjusted fitness: 0.249
# Mean genetic distance 2.081, standard deviation 0.305
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.313 sec (0.328 average)
#
#  ****** Running generation 188 ******
#
# Population's average fitness: 73.80000 stdev: 12.65385
# Best fitness: 122.00000 - size: (105, 7) - species 1 - id 9032
# Average adjusted fitness: 0.210
# Mean genetic distance 2.012, standard deviation 0.459
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.308 sec (0.327 average)
#
#  ****** Running generation 189 ******
#
# Population's average fitness: 74.86000 stdev: 12.51720
# Best fitness: 111.00000 - size: (104, 6) - species 1 - id 9094
# Average adjusted fitness: 0.277
# Mean genetic distance 2.059, standard deviation 0.419
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.321 sec (0.327 average)
#
#  ****** Running generation 190 ******
#
# Population's average fitness: 72.96000 stdev: 12.36116
# Best fitness: 108.00000 - size: (104, 6) - species 1 - id 9149
# Average adjusted fitness: 0.254
# Mean genetic distance 1.954, standard deviation 0.355
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.314 sec (0.325 average)
#
#  ****** Running generation 191 ******
#
# Population's average fitness: 71.10000 stdev: 8.85268
# Best fitness: 101.00000 - size: (105, 8) - species 1 - id 9211
# Average adjusted fitness: 0.252
# Mean genetic distance 2.009, standard deviation 0.327
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.373 sec (0.329 average)
#
#  ****** Running generation 192 ******
#
# Population's average fitness: 73.28000 stdev: 11.71160
# Best fitness: 105.00000 - size: (101, 0) - species 1 - id 9245
# Average adjusted fitness: 0.279
# Mean genetic distance 1.740, standard deviation 0.487
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.312 sec (0.322 average)
#
#  ****** Running generation 193 ******
#
# Population's average fitness: 70.60000 stdev: 9.89949
# Best fitness: 105.00000 - size: (101, 0) - species 1 - id 9303
# Average adjusted fitness: 0.218
# Mean genetic distance 1.802, standard deviation 0.410
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.317 sec (0.322 average)
#
#  ****** Running generation 194 ******
#
# Population's average fitness: 70.72000 stdev: 10.06785
# Best fitness: 111.00000 - size: (102, 1) - species 1 - id 9332
# Average adjusted fitness: 0.194
# Mean genetic distance 1.966, standard deviation 0.477
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.318 sec (0.322 average)
#
#  ****** Running generation 195 ******
#
# Population's average fitness: 70.80000 stdev: 9.09725
# Best fitness: 102.00000 - size: (104, 5) - species 1 - id 9390
# Average adjusted fitness: 0.239
# Mean genetic distance 1.932, standard deviation 0.456
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.315 sec (0.321 average)
#
#  ****** Running generation 196 ******
#
# Population's average fitness: 72.24000 stdev: 10.69123
# Best fitness: 108.00000 - size: (100, 1) - species 1 - id 9428
# Average adjusted fitness: 0.239
# Mean genetic distance 2.017, standard deviation 0.477
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.318 sec (0.321 average)
#
#  ****** Running generation 197 ******
#
# Population's average fitness: 71.26000 stdev: 9.92736
# Best fitness: 105.00000 - size: (102, 1) - species 1 - id 9500
# Average adjusted fitness: 0.250
# Mean genetic distance 1.915, standard deviation 0.459
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.308 sec (0.320 average)
#
#  ****** Running generation 198 ******
#
# Population's average fitness: 70.78000 stdev: 9.14831
# Best fitness: 93.00000 - size: (101, 0) - species 1 - id 9527
# Average adjusted fitness: 0.306
# Mean genetic distance 1.857, standard deviation 0.385
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.310 sec (0.321 average)
#
#  ****** Running generation 199 ******
#
# Population's average fitness: 70.04000 stdev: 9.44025
# Best fitness: 103.00000 - size: (100, 0) - species 1 - id 9555
# Average adjusted fitness: 0.215
# Mean genetic distance 1.965, standard deviation 0.473
# Population of 50 members in 1 species
# Total extinctions: 0
# Generation time: 0.301 sec (0.319 average)
#
# El mejor genoma:
# Key: 9555
# Fitness: 103
# Nodes:
# 	0 DefaultNodeGene(key=0, bias=0.5264125424857066, response=1.0, activation=relu, aggregation=sum)
# 	1 DefaultNodeGene(key=1, bias=-0.32502015081037294, response=1.0, activation=relu, aggregation=sum)
# 	2 DefaultNodeGene(key=2, bias=-1.164476825549956, response=1.0, activation=relu, aggregation=sum)
# 	3 DefaultNodeGene(key=3, bias=-0.5368541552370929, response=1.0, activation=relu, aggregation=sum)
# 	4 DefaultNodeGene(key=4, bias=0.8318017307558059, response=1.0, activation=relu, aggregation=sum)
# 	5 DefaultNodeGene(key=5, bias=0.5942042329628678, response=1.0, activation=relu, aggregation=sum)
# 	6 DefaultNodeGene(key=6, bias=2.0850021039292654, response=1.0, activation=relu, aggregation=sum)
# 	7 DefaultNodeGene(key=7, bias=1.7630558566128172, response=1.0, activation=relu, aggregation=sum)
# 	8 DefaultNodeGene(key=8, bias=0.16394427037398718, response=1.0, activation=relu, aggregation=sum)
# 	9 DefaultNodeGene(key=9, bias=-1.1670470041359162, response=1.0, activation=relu, aggregation=sum)
# 	10 DefaultNodeGene(key=10, bias=-0.6299098742922353, response=1.0, activation=relu, aggregation=sum)
# 	11 DefaultNodeGene(key=11, bias=0.9181463401635039, response=1.0, activation=relu, aggregation=sum)
# 	12 DefaultNodeGene(key=12, bias=0.5400884444747477, response=1.0, activation=relu, aggregation=sum)
# 	13 DefaultNodeGene(key=13, bias=-1.9337179961521154, response=1.0, activation=relu, aggregation=sum)
# 	14 DefaultNodeGene(key=14, bias=-0.18651083503670063, response=1.0, activation=relu, aggregation=sum)
# 	15 DefaultNodeGene(key=15, bias=0.5928953448717479, response=1.0, activation=relu, aggregation=sum)
# 	16 DefaultNodeGene(key=16, bias=0.9505300456004, response=1.0, activation=relu, aggregation=sum)
# 	17 DefaultNodeGene(key=17, bias=-1.5272733172262243, response=1.0, activation=relu, aggregation=sum)
# 	18 DefaultNodeGene(key=18, bias=-1.2598426094723563, response=1.0, activation=relu, aggregation=sum)
# 	19 DefaultNodeGene(key=19, bias=0.8685637010439609, response=1.0, activation=relu, aggregation=sum)
# 	20 DefaultNodeGene(key=20, bias=0.2956936667673404, response=1.0, activation=relu, aggregation=sum)
# 	21 DefaultNodeGene(key=21, bias=-1.8217414167383303, response=1.0, activation=relu, aggregation=sum)
# 	22 DefaultNodeGene(key=22, bias=1.971758933651845, response=1.0, activation=relu, aggregation=sum)
# 	23 DefaultNodeGene(key=23, bias=0.5365098640172126, response=1.0, activation=relu, aggregation=sum)
# 	24 DefaultNodeGene(key=24, bias=0.6519838195181652, response=1.0, activation=relu, aggregation=sum)
# 	25 DefaultNodeGene(key=25, bias=-0.37705247408253517, response=1.0, activation=relu, aggregation=sum)
# 	26 DefaultNodeGene(key=26, bias=0.7143337186861416, response=1.0, activation=relu, aggregation=sum)
# 	27 DefaultNodeGene(key=27, bias=-1.6885872375829967, response=1.0, activation=relu, aggregation=sum)
# 	28 DefaultNodeGene(key=28, bias=1.1347830737801754, response=1.0, activation=relu, aggregation=sum)
# 	29 DefaultNodeGene(key=29, bias=-0.4775798905922077, response=1.0, activation=relu, aggregation=sum)
# 	30 DefaultNodeGene(key=30, bias=0.5970580038475128, response=1.0, activation=relu, aggregation=sum)
# 	31 DefaultNodeGene(key=31, bias=1.299437870994507, response=1.0, activation=relu, aggregation=sum)
# 	32 DefaultNodeGene(key=32, bias=-1.9554281343112527, response=1.0, activation=relu, aggregation=sum)
# 	33 DefaultNodeGene(key=33, bias=1.7812752576657542, response=1.0, activation=relu, aggregation=sum)
# 	34 DefaultNodeGene(key=34, bias=-5.2380018874571395, response=1.0, activation=relu, aggregation=sum)
# 	35 DefaultNodeGene(key=35, bias=0.3528071609228983, response=1.0, activation=relu, aggregation=sum)
# 	36 DefaultNodeGene(key=36, bias=-0.37343617072702073, response=1.0, activation=relu, aggregation=sum)
# 	37 DefaultNodeGene(key=37, bias=-2.3582518309680527, response=1.0, activation=relu, aggregation=sum)
# 	38 DefaultNodeGene(key=38, bias=-2.495289232745099, response=1.0, activation=relu, aggregation=sum)
# 	39 DefaultNodeGene(key=39, bias=-1.254858664338894, response=1.0, activation=relu, aggregation=sum)
# 	40 DefaultNodeGene(key=40, bias=-0.950066199074898, response=1.0, activation=relu, aggregation=sum)
# 	41 DefaultNodeGene(key=41, bias=0.8919375850072402, response=1.0, activation=relu, aggregation=sum)
# 	42 DefaultNodeGene(key=42, bias=-0.3421742697783991, response=1.0, activation=relu, aggregation=sum)
# 	43 DefaultNodeGene(key=43, bias=1.2065459816307973, response=1.0, activation=relu, aggregation=sum)
# 	44 DefaultNodeGene(key=44, bias=-1.1281207465731158, response=1.0, activation=relu, aggregation=sum)
# 	45 DefaultNodeGene(key=45, bias=1.0047315411717674, response=1.0, activation=relu, aggregation=sum)
# 	46 DefaultNodeGene(key=46, bias=-0.911149916276383, response=1.0, activation=relu, aggregation=sum)
# 	47 DefaultNodeGene(key=47, bias=-0.22651774312187983, response=1.0, activation=relu, aggregation=sum)
# 	48 DefaultNodeGene(key=48, bias=-1.279448366040062, response=1.0, activation=relu, aggregation=sum)
# 	49 DefaultNodeGene(key=49, bias=0.025759327550596428, response=1.0, activation=relu, aggregation=sum)
# 	50 DefaultNodeGene(key=50, bias=-4.227176586490487, response=1.0, activation=relu, aggregation=sum)
# 	51 DefaultNodeGene(key=51, bias=0.5130231201029503, response=1.0, activation=relu, aggregation=sum)
# 	52 DefaultNodeGene(key=52, bias=0.4532689407723771, response=1.0, activation=relu, aggregation=sum)
# 	53 DefaultNodeGene(key=53, bias=-0.21986817964476507, response=1.0, activation=relu, aggregation=sum)
# 	54 DefaultNodeGene(key=54, bias=5.513318056137454, response=1.0, activation=relu, aggregation=sum)
# 	55 DefaultNodeGene(key=55, bias=-1.7043009851299564, response=1.0, activation=relu, aggregation=sum)
# 	56 DefaultNodeGene(key=56, bias=-1.7303606753253165, response=1.0, activation=relu, aggregation=sum)
# 	57 DefaultNodeGene(key=57, bias=-0.9588800658531978, response=1.0, activation=relu, aggregation=sum)
# 	58 DefaultNodeGene(key=58, bias=0.3191679141070522, response=1.0, activation=relu, aggregation=sum)
# 	59 DefaultNodeGene(key=59, bias=-0.4742846043992331, response=1.0, activation=relu, aggregation=sum)
# 	60 DefaultNodeGene(key=60, bias=1.792211506655238, response=1.0, activation=relu, aggregation=sum)
# 	61 DefaultNodeGene(key=61, bias=1.0613707729384743, response=1.0, activation=relu, aggregation=sum)
# 	62 DefaultNodeGene(key=62, bias=-3.02105329411252, response=1.0, activation=relu, aggregation=sum)
# 	63 DefaultNodeGene(key=63, bias=2.6927514902472516, response=1.0, activation=relu, aggregation=sum)
# 	64 DefaultNodeGene(key=64, bias=2.531026296505493, response=1.0, activation=relu, aggregation=sum)
# 	65 DefaultNodeGene(key=65, bias=2.1401479603839113, response=1.0, activation=relu, aggregation=sum)
# 	66 DefaultNodeGene(key=66, bias=0.2349316453823418, response=1.0, activation=relu, aggregation=sum)
# 	67 DefaultNodeGene(key=67, bias=-0.056027414792539934, response=1.0, activation=relu, aggregation=sum)
# 	68 DefaultNodeGene(key=68, bias=1.7490063040643806, response=1.0, activation=relu, aggregation=sum)
# 	69 DefaultNodeGene(key=69, bias=-0.788625882038011, response=1.0, activation=relu, aggregation=sum)
# 	70 DefaultNodeGene(key=70, bias=1.4561899358762962, response=1.0, activation=relu, aggregation=sum)
# 	71 DefaultNodeGene(key=71, bias=0.44453307688224347, response=1.0, activation=relu, aggregation=sum)
# 	72 DefaultNodeGene(key=72, bias=-2.2090637301568945, response=1.0, activation=relu, aggregation=sum)
# 	73 DefaultNodeGene(key=73, bias=-0.24702145020098595, response=1.0, activation=relu, aggregation=sum)
# 	74 DefaultNodeGene(key=74, bias=0.2816444698681643, response=1.0, activation=relu, aggregation=sum)
# 	75 DefaultNodeGene(key=75, bias=-1.940777953108652, response=1.0, activation=relu, aggregation=sum)
# 	76 DefaultNodeGene(key=76, bias=2.206427302322721, response=1.0, activation=relu, aggregation=sum)
# 	77 DefaultNodeGene(key=77, bias=0.8510092252366784, response=1.0, activation=relu, aggregation=sum)
# 	78 DefaultNodeGene(key=78, bias=1.6818745337619034, response=1.0, activation=relu, aggregation=sum)
# 	79 DefaultNodeGene(key=79, bias=1.059277601985033, response=1.0, activation=relu, aggregation=sum)
# 	80 DefaultNodeGene(key=80, bias=0.10676416973794953, response=1.0, activation=relu, aggregation=sum)
# 	81 DefaultNodeGene(key=81, bias=-0.08744850416216737, response=1.0, activation=relu, aggregation=sum)
# 	82 DefaultNodeGene(key=82, bias=-0.6729101565071345, response=1.0, activation=relu, aggregation=sum)
# 	83 DefaultNodeGene(key=83, bias=2.5649522895747046, response=1.0, activation=relu, aggregation=sum)
# 	84 DefaultNodeGene(key=84, bias=-0.12195918863395094, response=1.0, activation=relu, aggregation=sum)
# 	85 DefaultNodeGene(key=85, bias=-0.0775080271969677, response=1.0, activation=relu, aggregation=sum)
# 	86 DefaultNodeGene(key=86, bias=-0.6163134928575622, response=1.0, activation=relu, aggregation=sum)
# 	87 DefaultNodeGene(key=87, bias=-0.6372098621533233, response=1.0, activation=relu, aggregation=sum)
# 	88 DefaultNodeGene(key=88, bias=0.9975616058146661, response=1.0, activation=relu, aggregation=sum)
# 	89 DefaultNodeGene(key=89, bias=-1.7426796999972647, response=1.0, activation=relu, aggregation=sum)
# 	90 DefaultNodeGene(key=90, bias=0.2158121753674398, response=1.0, activation=relu, aggregation=sum)
# 	91 DefaultNodeGene(key=91, bias=-1.9821444793971446, response=1.0, activation=relu, aggregation=sum)
# 	92 DefaultNodeGene(key=92, bias=1.6910439695597754, response=1.0, activation=relu, aggregation=sum)
# 	93 DefaultNodeGene(key=93, bias=-0.07179943819093486, response=1.0, activation=relu, aggregation=sum)
# 	94 DefaultNodeGene(key=94, bias=2.3617161113724823, response=1.0, activation=relu, aggregation=sum)
# 	95 DefaultNodeGene(key=95, bias=1.4933403689701863, response=1.0, activation=relu, aggregation=sum)
# 	96 DefaultNodeGene(key=96, bias=2.273481487988908, response=1.0, activation=relu, aggregation=sum)
# 	97 DefaultNodeGene(key=97, bias=0.6951844425173873, response=1.0, activation=relu, aggregation=sum)
# 	98 DefaultNodeGene(key=98, bias=0.7738750912044963, response=1.0, activation=relu, aggregation=sum)
# 	99 DefaultNodeGene(key=99, bias=1.9070882840222096, response=1.0, activation=relu, aggregation=sum)
# Connections:
